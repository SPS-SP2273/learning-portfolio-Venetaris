# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Nice)</span></div>

# %% [markdown]
# # 1 If if is not enough

# %%
situation = "Bad"

match situation:
    case 'Good':
        print("Do a flip")
    case 'Neutral':
        print("Consume something")
    case 'Bad':
        print("Stop doomscrolling and paint ur minis")
    case _:
        print("Wut")
# Out:
# Stop doomscrolling and paint ur minis

# %% [markdown]
# # 2 Ternary operators or Conditional Statements

# %%
x,y = 5,5
if x == y:
    z = "yes"
z = "yes" if x == y

# %% [markdown]
# # 3 Swapping values

# %% [markdown]
# # 4 There are more types

# %% [markdown]
# # 5 Operator precedance

# %% [markdown]
# # 6 Variables in Python are just names

# %%
x = [1, 2]
y = x
y.append(3)

print(f"x: {x}, y: {y}")
x is y
# Out:
# x: [1, 2, 3], y: [1, 2, 3]
# True

# %% [markdown]
# Oh yeah because they are legitimately linked so same id

# %%
x = [1, 2]
y = x.copy()
y.append(3)

print(f"x: {x}, y: {y}")
x is y
# Out:
# x: [1, 2], y: [1, 2, 3]
# False

# %% [markdown]
# ## 6.1 The Problem

# %% [markdown]
# ## 6.2 An explanation

# %% [markdown]
# ## 6.3 A solution

# %% [markdown]
# # 7 == is not the same as is

# %% [markdown]
# ## Footnotes
