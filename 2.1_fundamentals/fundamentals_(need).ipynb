# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Functions

# %%
print('Hello World')
# Out:
# Hello World

# %%
def function(arg):
# Out:
#   Cell In[4], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# # 2 Python is interpreted

# %% [markdown]
# I.e. one line at a time, alternative is compiled language, which creates executable that is then run. Slower than compiled languages but doesn't really matter rn.
# Also also Jupyter variables exist

# %% [markdown]
# # 3 Python is sensitive.

# %%
pRinT() # Doesn't work

# %% [markdown]
# # 4 Comments

# %%
print("Nope") #Hello

# %% [markdown]
# # 5 = is not the same as ==

# %% [markdown]
# # 6 Use if to make decisions

# %% [markdown]
# # 7 Indentations (spaces) are sooo IMPORTANT!

# %% [markdown]
# # 8 ‘age’ is English, age is a variable.

# %%
age = 24
print(age)

# %% [markdown]
# # 9 Brackets

# %%
List2 = [
    ["A", 20],
    ["B", 55]
]
print(List2)

# %% [markdown]
# # 10 Giving Python superpowers with Packages

# %% [markdown]
# ## 10.1 Some Context

# %%
#Forbidden knowledge
from numpy import * #Dont lol it adds everything to the active environment then it'll cause conflicts
# Best to use only when you know you are going to use one package 
from numpy import sqrt # Imports only 1 function, no need to call later on
# Importing only ever occurs once unless told to do so

# %% [markdown]
# ## 10.2 Importing the math package

# %%
import math as m # m as alias
m.sqrt(4)

# %% [markdown]
# ## 10.3 Importing the numpy package

# %%
import numpy as np
np.sqrt(4)

# %% [markdown]
# ## 10.4 Why so many packages?

# %% [markdown]
# # 11 The dot (.)

# %% [markdown]
# . is for attributes, rmb when making variable names (use _ instead)
# Object oriented language, everything is an object with things attached to it

# %%
"the end and the death".title()
123.0.__float__()
# Out:
# 123.0

# %% [markdown]
# ## Footnotes
