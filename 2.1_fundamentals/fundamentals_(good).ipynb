# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 There is more to if

# %%
x = 4

if x >= 5:
    print("Large")
elif x >= 3:
    print("Medium") #ELIF unto infinity
else:
    print("Small")
# Out:
# Medium

# %% [markdown]
# # 2 Asking questions

# %%
"Fine" not in "Settimana" and True or False
# Also works with individual letters in str
'e' in 'Fine'
'apples' > 'a' # in strings, comparisons are pre-defined, strings are numbers ultimately
# Out:
# True

# %% [markdown]
# ## 2.1 Asking Math questions

# %%
# Same as in R

# %% [markdown]
# # 3 Python stores information in different formats or types

# %%
a = int(6.7421)
b = str(6.7421)
c = float(6.7421)
d = complex(6.7421)
print(a, type(a), b, type(b), c, type(c), d, type(d)) #Called casting
#Reasons for casting: computer can only hold so many numbers, 64-bit pcs means dataflow is restricted to 64 lines, so maximum value is 2^64
# Numpy saves array as integer or float, and gets a definite amount of memory associated with it, so operations can be very fast
# Data types are for physical computers
# Out:
# 6 <class 'int'> 6.7421 <class 'str'> 6.7421 <class 'float'> (6.7421+0j) <class 'complex'>
# 18446744073709551616

# %% [markdown]
# # 4 Never compare floats directly

# %%
a = 0.1
a3 = 0.3
a * 3 == a3
print(a)
print(a3)
# Out:
# 0.1
# 0.3

# %% [markdown]
# But why tho

# %% [markdown]
# ## 4.1 The Problem

# %% [markdown]
# ## 4.2 A solution

# %%
import numpy as np
a = 0.1
a3 = 0.1*3
np.isclose (a*3, a3)
# Out:
# np.True_

# %% [markdown]
# # 5 Combining English and variables

# %%
x = 50
print(f"The value of {x} squared is {x**2}!")
# Out:
# The value of 50 squared is 2500!

# %% [markdown]
# Takeaway: Use f string to mix variables and variables up to create adaptable messages
# f-strings are useful for this, variables in { a } as internals are executed as code

# %% [markdown]
# ## 5.1 Structure of f-strings

# %%
X = 67
print(f"Practice in using f-strings with the format {X:>4.2f} hmmmm")
# Out:
# Practice in using f-strings with the format 67.00 hmmmm

# %% [markdown]
# # 6 Escape sequences

# %%
print('You\'re amazing \\s \n \t Maybe?')
# Out:
# You're amazing \s
#  	 Maybe?

# %% [markdown]
# ## 6.1 Self-documenting f-strings

# %%
a,b = 50/6, 27^2
print(f"{a=:.3f} and {b=:.3f}")
# Out:
# a=8.333 and b=25.000

# %% [markdown]
# # 7 Computers read = from Right to Left!

# %%
x = 40
y = x + 2
print(y)
# Out:
# 42

# %%
y = 40 
y = y + 2
print(y)
# Out:
# 42

# %% [markdown]
# # 8 Shorter and Cleaner Code

# %%
#Alter single variable with
y = 35
y += 2
print(y)
y -= 4
print(y)
y *= 2
print(y)
y /= 3
print(y)
# Out:
# 37
# 33
# 66
# 22.0

# %% [markdown]
# # 9 Python can be a prima-donna.

# %% [markdown]
# # 10 Best Practices for Scientific Computing

# %% [markdown]
# Basically just try to make it explainable

# %% [markdown]
# # 11 Looking for help

# %%
help(help)
# Out:
# Help on _Helper in module _sitebuiltins object:
#
# class _Helper(builtins.object)
#  |  Define the builtin 'help'.
#  |
#  |  This is a wrapper around pydoc.help that provides a helpful message
#  |  when 'help' is typed at the Python interactive prompt.
#  |
#  |  Calling help() at the Python prompt starts an interactive help session.
#  |  Calling help(thing) prints help for the python object 'thing'.
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, *args, **kwds)
#  |      Call self as a function.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %% [markdown]
# ## References

# %% [markdown]
# ## Footnotes
