# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Some tips and tricks

# %% [markdown]
# ## 1.1 Keyboard Shortcuts

# %% [markdown]
# ### Things to note

# %%
# Don't forget shift + enter
# worse come to worse use esc + h (only for jupyter)
# don't delete cells unless absolutely certain
# rmb esc is a toggle not a hold

# %%
# cell created using esc + a

# %%
# cell created using esc + b

# %% [markdown]
# ## 1.2 Shell commands

# %%
# !cd
# Out:
# c:\Users\Issac\Documents\learning-portfolio-Venetaris\1.1_using_jupyter

# %% [markdown]
# # 2 Install Notebook 7

# %% [markdown]
# We are currently at 7.5.2, update irrelevant

# %% [markdown]
# # Jupyter Extensions

# %% [markdown]
# Extensions dead lmao

# %% [markdown]
# ## Installing the extensions

# %% [markdown]
# ## Enabling the extensions

# %% [markdown]
# # 3 Shell Magic

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %timeit x = 10
# Out:
# 21.6 ns ± 5.13 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# # 4 The Kernel

# %% [markdown]
# Kernel identified. currently base python 3.13.11

# %% [markdown]
# List practice
# 1. WHooo three lines at once baybeeeeee
# 1. WHooo three lines at once baybeeeeee
# 1. WHooo three lines at once baybeeeeee
