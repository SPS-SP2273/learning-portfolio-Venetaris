# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while FALSE:
    print('*', end='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 while FALSE:
#       2     print('*', end='')
#
# NameError: name 'FALSE' is not defined

# %%
# print = 'PRINT'
print('Hello World')
print('WHYYYYYYYYYY')
# Out:
# Hello World
# WHYYYYYYYYYY

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 895 ns ± 50.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 1.24 μs ± 70.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# List of squares are the same
# 1st one is 895 nanoseconds per loop, 2nd is 1.24 microseconds per loop. Time taken for interpreter to execute each block of code, 2nd block is less efficient than the first as it involves more operations.

# %% [markdown]
# ## Footnotes
